# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Analise exploratoria do primeiro dataset (producao-de-plastico-global)
#
# * atribuição do dataframe na variavel df1
# * Informações sobre df1
# * tratamento dos dados, exclusão dos dados faltantes e duplicados
# * grafico
# * considerações finais

# %%
df1 = pd.read_csv('1- producao-de-plastico-global.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Entidade                    69 non-null     object
#  1   Ano                         69 non-null     int64
#  2   Produção Anual de Plástico  69 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.7+ KB

# %%
df1= df1.dropna()
df1 = df1.drop_duplicates()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Entidade                    69 non-null     object
#  1   Ano                         69 non-null     int64
#  2   Produção Anual de Plástico  69 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.7+ KB

# %%
sns.scatterplot(df1, x='Ano', y='Produção Anual de Plástico', hue='Produção Anual de Plástico', palette='viridis')
# Out:
# <Axes: xlabel='Ano', ylabel='Produção Anual de Plástico'>

# %% [markdown]
# Como podemos observar no grafico, a produção de plastico tem um crescimento exponencial, em 1950, a produção anual era de 2 milhões de toneladas, crescendo para quase 460 milhões de toneladas em 2019.
#
# Também conseguimos constatar um crescimento recente na ultima decada (2010-2019), onde a produção aumentou de 313 milhões para 460 milhões de toneladas, indicando uma grande demanda por plástico.
#
# O aumento exponencial na produção de plpastico destaca diversas preocupações ambientais, principalmente pela poluição por microplasticos, isso reforça a necessidade de soluções sustentaveis de reciclagem para preservar o meio ambiente.
#
#
# ref: [https://mundoeducacao.uol.com.br/quimica/microplasticos.htm]

# %% [markdown]
# ## Analise do segundo dataset (participacao-despejo-residuo-plastico.csv)
#
#
# * atribuição do dataframe na variavel df2
# * Informações sobre df2
# * tratamento dos dados, exclusão dos dados faltantes e duplicados
# * grafico de pares
# * considerações finais

# %%
df2 = pd.read_csv('2- participacao-despejo-residuo-plastico.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 4 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Entidade                                                   170 non-null    object
#  1   Código                                                     159 non-null    object
#  2   Ano                                                        170 non-null    int64
#  3   Participação na emissão global de plásticos para o oceano  170 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 5.4+ KB

# %%
df2 = df2.dropna()
df2 = df2.drop_duplicates()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159 entries, 1 to 169
# Data columns (total 4 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Entidade                                                   159 non-null    object
#  1   Código                                                     159 non-null    object
#  2   Ano                                                        159 non-null    int64
#  3   Participação na emissão global de plásticos para o oceano  159 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ KB

# %%
plt.figure(figsize=(15, 8))  
sns.barplot(data=df2, x='Código', y='Participação na emissão global de plásticos para o oceano')
plt.title('Participação na emissão global de plásticos para o oceano por Entidade')
plt.xticks(rotation=90, ha='right', fontsize=6)  
plt.tight_layout()  
plt.show()

# %% [markdown]
# O Grafico acima mostra a relação dos paises com suas respectivas participações na emissão global de plasticos, por serem varios países a visualização fica um pouco comprometida, por esse motivo resolvi "quebrar o grafico" em alguns pontos especificos que poderão ser vistos abaixo.

# %%
top10 = df2.nlargest(10, 'Participação na emissão global de plásticos para o oceano')
plt.xticks(rotation=45)
sns.barplot(data=top10, x='Entidade', y='Participação na emissão global de plásticos para o oceano')
# Out:
# <Axes: xlabel='Entidade', ylabel='Participação na emissão global de plásticos para o oceano'>

# %% [markdown]
# No top 5 maiores emissores de plasticos, todos os países são da Asia. Não só isso, como cerca de 80% de toda a emissão de plastico vem da Ásia. O Brasil ocupa a sexta posição no ranking, sendo o unico país da ámerica do sul no top 10.

# %% [markdown]
# ## Analise do terceiro dataset (3 - destino-plastico.csv)
#
#
# * atribuição do dataframe na variavel df3
# * Informações sobre df3
# * tratamento dos dados, exclusão dos dados faltantes e duplicados
# * graficos
# * considerações finais

# %%
df3 = pd.read_csv('3- destino-plastico.csv')
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Entidade                                                          200 non-null    object
#  1    Código                                                           80 non-null     object
#  2    Ano                                                              200 non-null    int64
#  3    Participação da reciclagem do lixo total regional                200 non-null    float64
#  4    Participação da queima do lixo total regional                    200 non-null    float64
#  5    Participação do lixo descartado e mal gerido do total regional   200 non-null    float64
#  6    Participação do lixo encaminhado para aterros do total regional  200 non-null    float64
# ...

# %%
#Remoção da coluna ' Código' que não será utilizada
df3 = df3.drop(columns=[' Código'], axis=1)

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(data=df3, x="Entidade", y=" Participação da reciclagem do lixo total regional")
plt.title("Comparação da Participação da Reciclagem do Lixo Total Regional dentre todas as Regiões")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(data=df3, x="Entidade", y=" Participação do lixo descartado e mal gerido do total regional")
plt.title("Comparação da Participação do Lixo Descartado e Mal Gerido entre Regiões")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Embora a China e a India sejam os países que mais reciclam, eles também conseguem ser os países que pior gerem o lixo, isso se dá provavelmente pelo grande acumulo de plastico na região.

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(data=df3, x="Entidade", y=" Participação da queima do lixo total regional")
plt.title("Comparação da Participação da Queima do Lixo Total Regional entre Regiões")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(data=df3, x="Entidade", y=" Participação do lixo encaminhado para aterros do total regional")
plt.title("Comparação da Participação do lixo encaminhado para aterros do total regional entre Regiões")
plt.xticks(rotation=45)
plt.show()

# %%
df_melted = df3.melt(id_vars='Entidade', 
                     value_vars=[' Participação da reciclagem do lixo total regional', 
                                 ' Participação do lixo descartado e mal gerido do total regional', 
                                 ' Participação da queima do lixo total regional', 
                                 ' Participação do lixo encaminhado para aterros do total regional'], 
                     var_name='Categoria', 
                     value_name='Valor')

plt.figure(figsize=(14, 8))
sns.boxplot(data=df_melted, x="Entidade", y="Valor", hue="Categoria")
plt.title("Comparação da Participação do Lixo Total Regional entre Regiões")
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# num panorama geral, quando falamos sobre o mundo como um todo, ainda existe muito descaso com a reciclagem de lixo e a solução mais simples (porem ecologicamente errada) é utilizar de aterros. China, India são os campeões em descarte incorreto, junto de sub-saharan Africa.

# %% [markdown]
# ## Analise do quarto dataset (4 - desperdicio-plastico-per-capita)
#
#
# * atribuição do dataframe na variavel df4
# * Informações sobre df4
# * tratamento dos dados, exclusão dos dados faltantes e duplicados
# * graficos
# * considerações finais

# %%
df4 = pd.read_csv('4- desperdicio-plastico-per-capita.csv')

# %%
df4.drop_duplicates()
df4.drop(columns=[' Código'], axis=1)
# Out:
#                 Entidade   Ano  \
# 0                 Africa  2019
# 1                Albania  2019
# 2                Algeria  2019
# 3                 Angola  2019
# 4    Antigua and Barbuda  2019
# ..                   ...   ...
# 160              Vietnam  2019
# 161       Western Sahara  2019
# 162                World  2019
# 163                Yemen  2019
# 164             Zimbabwe  2019
#
#       Lixo plástico mal gerenciado por pessoa (kg por ano)
# 0                                            10.465928
# 1                                            24.239153
# 2                                            17.758995
# 3                                             7.445279
# 4                                             6.463918
# ..                                                 ...
# 160                                          11.536045
# 161                                           7.068729
# 162                                           8.008551
# ...

# %%
# Filtrar os 10 maiores e menores valores
top_10 = df4.nlargest(10, " Lixo plástico mal gerenciado por pessoa (kg por ano)")
bottom_10 = df4.nsmallest(10, " Lixo plástico mal gerenciado por pessoa (kg por ano)")

# Configurar o estilo do seaborn
sns.set_theme(style="whitegrid")

# Gráfico de barras horizontais para top 10
plt.figure(figsize=(12, 6))
sns.barplot(x=" Lixo plástico mal gerenciado por pessoa (kg por ano)", y="Entidade", data=top_10, palette="viridis")
plt.title("Top 10 Países com Maior Lixo Plástico Mal Gerenciado por Pessoa (2019)")
plt.xlabel("Lixo Plástico Mal Gerenciado (kg/pessoa/ano)")
plt.ylabel("País")
plt.show()

# Gráfico de barras horizontais para bottom 10
plt.figure(figsize=(12, 6))
sns.barplot(x=" Lixo plástico mal gerenciado por pessoa (kg por ano)", y="Entidade", data=bottom_10, palette="viridis")
plt.title("Top 10 Países com Menor Lixo Plástico Mal Gerenciado por Pessoa (2019)")
plt.xlabel("Lixo Plástico Mal Gerenciado (kg/pessoa/ano)")
plt.ylabel("País")
plt.show()
# Out:
# C:\Users\nimar\AppData\Local\Temp\ipykernel_312\963125078.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=" Lixo plástico mal gerenciado por pessoa (kg por ano)", y="Entidade", data=top_10, palette="viridis")
# C:\Users\nimar\AppData\Local\Temp\ipykernel_312\963125078.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=" Lixo plástico mal gerenciado por pessoa (kg por ano)", y="Entidade", data=bottom_10, palette="viridis")

# %% [markdown]
# Os 10 países com maior quantidade de lixo plástico mal gerenciado variam de 23.5 a 69.5 kg por pessoa por ano.
# Comores lidera com 69.5 kg, seguido por Trinidad e Tobago (52.4 kg) e Suriname (39.5 kg).
# A maioria dos países com altos valores são nações insulares ou países em desenvolvimento.

# %% [markdown]
# Os 10 países com menor quantidade de lixo plástico mal gerenciado têm valores abaixo de 0.45 kg por pessoa por ano.
# Coreia do Norte tem o menor valor, com apenas 0.0125 kg, seguida por Montenegro (0.0255 kg) e Síria (0.0294 kg).
# Países desenvolvidos, como Bélgica e Dinamarca, também apresentam baixos valores.

# %%
median_value = df4[" Lixo plástico mal gerenciado por pessoa (kg por ano)"].median()
print(f"A Mediana do desperdício de plástico por pessoa: {median_value:.2f} kg/ano")
# Out:
# A Mediana do desperdício de plástico por pessoa: 5.98 kg/ano
